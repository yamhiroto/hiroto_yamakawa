# %%
import pandas as pd
from datetime import datetime

# %%
df_pop = pd.read_csv('population_communes.csv')

df_surf = pd.read_csv('surface_departements.csv')

# %%
df_surf.head()
# Out:
#   code_insee               nom  surf_km2
# 0        974        La Réunion    2505.0
# 1         11              Aude    6343.0
# 2         43       Haute-Loire    5003.0
# 3         13  Bouches-du-Rhône    5247.0
# 4         47    Lot-et-Garonne    5385.0

# %%
df_pop = df.rename(columns={'Code région' : 'code_region', 'Code département' : 'code_dept'})

# %%
df_pop
# Out:
#      code_region code_dept               variable   value
# 0              1       971  Population municipale  394110
# 1              1       971      Population totale  400170
# 2              2       972  Population municipale  376480
# 3              2       972      Population totale  382294
# 4              3       973  Population municipale  269352
# ..           ...       ...                    ...     ...
# 195           93        84      Population totale  570921
# 196           94        2A  Population municipale  154303
# 197           94        2A      Population totale  156958
# 198           94        2B  Population municipale  176152
# 199           94        2B      Population totale  179037
#
# [200 rows x 4 columns]

# %%
df_pop.groupby(['code_region','code_dept','variable'])['value'].sum().reset_index()
# Out:
#      code_region code_dept               variable   value
# 0              1       971  Population municipale  394110
# 1              1       971      Population totale  400170
# 2              2       972  Population municipale  376480
# 3              2       972      Population totale  382294
# 4              3       973  Population municipale  269352
# ..           ...       ...                    ...     ...
# 195           93        84      Population totale  570921
# 196           94        2A  Population municipale  154303
# 197           94        2A      Population totale  156958
# 198           94        2B  Population municipale  176152
# 199           94        2B      Population totale  179037
#
# [200 rows x 4 columns]

# %%
df_pop.sort_values(by=['Nom de la commune']).head()
# Out:
#   Code département  Code canton  Code arrondissement  Code région  \
# 0               64         27.0                    3           75
# 1               64         27.0                    3           75
# 2               55         10.0                    2           44
# 3               55         10.0                    2           44
# 4               60         11.0                    1           32
#
#   Nom de la commune  Code commune    Nom de la région               variable  \
# 0              Aast             1  Nouvelle-Aquitaine      Population totale
# 1              Aast             1  Nouvelle-Aquitaine  Population municipale
# 2        Abainville             1           Grand Est      Population totale
# 3        Abainville             1           Grand Est  Population municipale
# 4         Abancourt             1     Hauts-de-France      Population totale
#
#    value
# 0    184
# 1    177
# 2    310
# 3    305
# 4    658

# %%
df = df_pop.groupby(['Code région','Code département', 'variable']).sum().reset_index()[['Code région','Code département', 'variable', 'value']]

# %%
df.head()
# Out:
#    Code région Code département               variable   value
# 0            1              971  Population municipale  394110
# 1            1              971      Population totale  400170
# 2            2              972  Population municipale  376480
# 3            2              972      Population totale  382294
# 4            3              973  Population municipale  269352

# %%
df_surf.columns = ['Code département','Nom du département', 'surf_km2']

# %%
df_test = pd.merge(df_pop, df_surf, how="left", on=["Code département"])

# %%
df_test2 = df_test.dropna()

# %%
df_test2.sort_values(by = ['Code département'])
# Out:
#       Code département  Code canton  Code arrondissement  Code région  \
# 5504                01          3.0                    4           84
# 11625               01         16.0                    4           84
# 33287               01          7.0                    2           84
# 33286               01          7.0                    2           84
# 49010               01         22.0                    2           84
# ...                ...          ...                  ...          ...
# 33921              974         14.0                    4            4
# 59403              974          8.0                    3            4
# 59405              974          8.0                    3            4
# 59252              974         23.0                    1            4
# 27575              974          1.0                    2            4
#
#               Nom de la commune  Code commune      Nom de la région  \
# ...

# %%
df_test3 = df_test2.drop_duplicates(['Code département','Code commune']).sort_values(by = ['Code département'])

# %%
df_test4 = df_test3.groupby(by = ['Code département'])

# %%
df

# %%
df_test4['variable' == 'Population totale']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-6bca63ac0033> in <module>
# ----> 1 df_test4['variable' == 'Population totale']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in __getitem__(self, key)
#     266         else:
#     267             if key not in self.obj:
# --> 268                 raise KeyError("Column not found: {key}".format(key=key))
#     269             return self._gotitem(key, ndim=1)
#     270
#
# KeyError: 'Column not found: False'

# %%
pd.read_csv('result-exo-cc.csv')
# Out:
#                    nom_dept code_dept  code_region  pop_municipale  \
# 0                       Ain        01           84          638425
# 1                     Aisne        02           32          536136
# 2                    Allier        03           84          339384
# 3   Alpes-de-Haute-Provence        04           93          162565
# 4              Hautes-Alpes        05           93          141107
# ..                      ...       ...          ...             ...
# 95               Val-d'Oise        95           11         1221923
# 96               Guadeloupe       971            1          394110
# 97               Martinique       972            2          376480
# 98                   Guyane       973            3          269352
# 99               La Réunion       974            4          852924
#
#     pop_totale  pct_pop_municipale  part_region     densite
# 0       655171           97.444026     8.064089  110.377766
# ...
